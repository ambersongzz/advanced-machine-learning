# %% [markdown]
# # Q 1, 2

# %% [markdown]
# ![title](Q1.jpg)

# %% [markdown]
# ![title](Q2.jpg)

# %% [markdown]
# # Q 3

# %%
import argparse
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.autograd import Variable
from torch.utils.data import Dataset
import pandas as pd
import numpy as np
# Out:
# /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/matplotlib/__init__.py:962: UserWarning: Duplicate key in file "/home/ec2-user/.config/matplotlib/matplotlibrc", line #2
#   (fname, cnt))
# /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/matplotlib/__init__.py:962: UserWarning: Duplicate key in file "/home/ec2-user/.config/matplotlib/matplotlibrc", line #3
#   (fname, cnt))

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/matplotlib/font_manager.py:281: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   'Matplotlib is building the font cache using fc-list. '

# %%
train_ds = datasets.MNIST('data', train=True, download=True, 
                       transform=transforms.Compose([
                       transforms.ToTensor(),
                       transforms.Normalize((0.1307,), (0.3081,))
                   ]))
test_ds = datasets.MNIST('data', train=False, download=True, 
                       transform=transforms.Compose([
                       transforms.ToTensor(),
                       transforms.Normalize((0.1307,), (0.3081,))
                   ]))
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Processing...
# Done!

# %%
batch_size = 64
kwargs = {'num_workers': 1, 'pin_memory': True} 

train_loader = torch.utils.data.DataLoader(train_ds, batch_size=batch_size, shuffle=True, **kwargs)
test_loader = torch.utils.data.DataLoader(test_ds, batch_size=batch_size, shuffle=False, **kwargs)

# %%
# for the number of neurons in the hidden unit
def get_model(M = 300):
    net = nn.Sequential(nn.Linear(28*28, M),
                        nn.ReLU(),
                        nn.Linear(M, 10))
    return net.cuda()

# %%
def train_model(train_loader, test_loader, num_epochs, model, optimizer):
    for epoch in range(num_epochs):
        model.train()
        sum_loss = 0.0
        total = 0
        for i, (images, labels) in enumerate(train_loader):  
            batch = images.shape[0] # size of the batch
            # Convert torch tensor to Variable, change shape of the input
            images = Variable(images.view(-1, 28*28)).cuda()
            labels = Variable(labels).cuda()
        
            # Forward + Backward + Optimize
            optimizer.zero_grad()  # zero the gradient buffer
            outputs = model(images)
            loss = F.cross_entropy(outputs, labels)
            loss.backward()
            optimizer.step()
        
            total += batch
            sum_loss += batch * loss.data[0]
                
        train_loss = sum_loss/total
        print('Epoch [%d/%d], Loss: %.4f' %(epoch+1, num_epochs, train_loss))
        val_acc, val_loss = model_accuracy_loss(model, test_loader)
        print('Epoch [%d/%d], Valid Accuracy: %.4f, Valid Loss: %.4f' %(epoch+1, num_epochs, val_acc, val_loss))
    return val_acc, val_loss, train_loss

# %%
def model_accuracy_loss(model, test_loader):
    model.eval()
    correct = 0
    sum_loss = 0.0
    total = 0
    for images, labels in test_loader:
        images = Variable(images.view(-1, 28*28)).cuda()
        labels = Variable(labels).cuda()
        outputs = model(images)
        _, pred = torch.max(outputs.data, 1)
        loss = F.cross_entropy(outputs, labels)
        sum_loss += labels.size(0)*loss.data[0]
        total += labels.size(0)
        correct += pred.eq(labels.data).cpu().sum()
    return 100 * correct / total, sum_loss/ total

# %% [markdown]
# ## Q 3.1

# %%
# %%time
learning_rates = [1, 0.1, 0.01, 0.001, 0.0001, 0.00001]
val_accs = []

for r in learning_rates:
    net = get_model()
    optimizer = optim.Adam(net.parameters(), lr=r)
    val_acc = train_model(train_loader, test_loader, num_epochs=10, model=net, optimizer=optimizer)[0]
    val_accs.append(val_acc)
# Out:
# Epoch [1/10], Loss: 124.5998
# Epoch [1/10], Valid Accuracy: 11.4000, Valid Loss: 3.0034
# Epoch [2/10], Loss: 2.5318
# Epoch [2/10], Valid Accuracy: 9.8400, Valid Loss: 2.9144
# Epoch [3/10], Loss: 2.3731
# Epoch [3/10], Valid Accuracy: 10.1600, Valid Loss: 2.9165
# Epoch [4/10], Loss: 2.3663
# Epoch [4/10], Valid Accuracy: 9.8500, Valid Loss: 2.9412
# Epoch [5/10], Loss: 2.3675
# Epoch [5/10], Valid Accuracy: 10.3400, Valid Loss: 2.8960
# Epoch [6/10], Loss: 2.3794
# Epoch [6/10], Valid Accuracy: 10.3400, Valid Loss: 2.9082
# Epoch [7/10], Loss: 2.3738
# Epoch [7/10], Valid Accuracy: 10.3400, Valid Loss: 2.9277
# Epoch [8/10], Loss: 2.3637
# Epoch [8/10], Valid Accuracy: 9.8100, Valid Loss: 2.9689
# Epoch [9/10], Loss: 2.3852
# Epoch [9/10], Valid Accuracy: 9.8100, Valid Loss: 2.8988
# Epoch [10/10], Loss: 2.3752
# Epoch [10/10], Valid Accuracy: 9.8500, Valid Loss: 2.9238
# Epoch [1/10], Loss: 3.0976
# Epoch [1/10], Valid Accuracy: 29.7000, Valid Loss: 1.8964
# Epoch [2/10], Loss: 2.1077
# Epoch [2/10], Valid Accuracy: 11.4300, Valid Loss: 2.3075
# Epoch [3/10], Loss: 2.3143
# Epoch [3/10], Valid Accuracy: 11.3600, Valid Loss: 2.3064
# Epoch [4/10], Loss: 2.3131
# Epoch [4/10], Valid Accuracy: 10.1200, Valid Loss: 2.3090
# Epoch [5/10], Loss: 2.3108
# Epoch [5/10], Valid Accuracy: 9.8300, Valid Loss: 2.3161
# Epoch [6/10], Loss: 2.3105
# Epoch [6/10], Valid Accuracy: 11.3600, Valid Loss: 2.3188
# Epoch [7/10], Loss: 2.3100
# Epoch [7/10], Valid Accuracy: 9.8300, Valid Loss: 2.3054
# Epoch [8/10], Loss: 2.3093
# Epoch [8/10], Valid Accuracy: 9.7700, Valid Loss: 2.3147
# Epoch [9/10], Loss: 2.3096
# Epoch [9/10], Valid Accuracy: 9.5800, Valid Loss: 2.3069
# Epoch [10/10], Loss: 2.3102
# Epoch [10/10], Valid Accuracy: 11.3500, Valid Loss: 2.3103
# Epoch [1/10], Loss: 0.2871
# Epoch [1/10], Valid Accuracy: 93.3100, Valid Loss: 0.2393
# Epoch [2/10], Loss: 0.1981
# Epoch [2/10], Valid Accuracy: 93.9700, Valid Loss: 0.2297
# Epoch [3/10], Loss: 0.1953
# Epoch [3/10], Valid Accuracy: 94.8900, Valid Loss: 0.2094
# Epoch [4/10], Loss: 0.1724
# Epoch [4/10], Valid Accuracy: 94.4900, Valid Loss: 0.2219
# Epoch [5/10], Loss: 0.1749
# Epoch [5/10], Valid Accuracy: 95.3300, Valid Loss: 0.2151
# Epoch [6/10], Loss: 0.1613
# Epoch [6/10], Valid Accuracy: 94.8500, Valid Loss: 0.2777
# Epoch [7/10], Loss: 0.1608
# Epoch [7/10], Valid Accuracy: 94.7600, Valid Loss: 0.2294
# Epoch [8/10], Loss: 0.1565
# Epoch [8/10], Valid Accuracy: 95.1100, Valid Loss: 0.2502
# Epoch [9/10], Loss: 0.1571
# Epoch [9/10], Valid Accuracy: 94.3000, Valid Loss: 0.2892
# Epoch [10/10], Loss: 0.1503
# Epoch [10/10], Valid Accuracy: 94.8800, Valid Loss: 0.2562
# Epoch [1/10], Loss: 0.2205
# Epoch [1/10], Valid Accuracy: 96.4100, Valid Loss: 0.1165
# Epoch [2/10], Loss: 0.0937
# Epoch [2/10], Valid Accuracy: 97.2700, Valid Loss: 0.0843
# Epoch [3/10], Loss: 0.0630
# Epoch [3/10], Valid Accuracy: 97.5500, Valid Loss: 0.0750
# Epoch [4/10], Loss: 0.0466
# Epoch [4/10], Valid Accuracy: 97.5600, Valid Loss: 0.0787
# Epoch [5/10], Loss: 0.0348
# Epoch [5/10], Valid Accuracy: 97.4600, Valid Loss: 0.0864
# Epoch [6/10], Loss: 0.0296
# Epoch [6/10], Valid Accuracy: 97.7500, Valid Loss: 0.0771
# Epoch [7/10], Loss: 0.0244
# Epoch [7/10], Valid Accuracy: 97.6000, Valid Loss: 0.0826
# Epoch [8/10], Loss: 0.0219
# Epoch [8/10], Valid Accuracy: 97.9400, Valid Loss: 0.0751
# Epoch [9/10], Loss: 0.0195
# Epoch [9/10], Valid Accuracy: 97.8300, Valid Loss: 0.0906
# Epoch [10/10], Loss: 0.0145
# Epoch [10/10], Valid Accuracy: 98.0600, Valid Loss: 0.0740
# Epoch [1/10], Loss: 0.4868
# Epoch [1/10], Valid Accuracy: 92.7300, Valid Loss: 0.2603
# Epoch [2/10], Loss: 0.2343
# Epoch [2/10], Valid Accuracy: 94.1600, Valid Loss: 0.2016
# Epoch [3/10], Loss: 0.1802
# Epoch [3/10], Valid Accuracy: 95.2000, Valid Loss: 0.1615
# Epoch [4/10], Loss: 0.1460
# Epoch [4/10], Valid Accuracy: 95.9400, Valid Loss: 0.1393
# Epoch [5/10], Loss: 0.1217
# Epoch [5/10], Valid Accuracy: 96.5600, Valid Loss: 0.1203
# Epoch [6/10], Loss: 0.1038
# Epoch [6/10], Valid Accuracy: 96.8700, Valid Loss: 0.1063
# Epoch [7/10], Loss: 0.0893
# Epoch [7/10], Valid Accuracy: 97.0100, Valid Loss: 0.0977
# Epoch [8/10], Loss: 0.0783
# Epoch [8/10], Valid Accuracy: 97.2700, Valid Loss: 0.0909
# Epoch [9/10], Loss: 0.0690
# Epoch [9/10], Valid Accuracy: 97.6400, Valid Loss: 0.0836
# Epoch [10/10], Loss: 0.0608
# Epoch [10/10], Valid Accuracy: 97.6700, Valid Loss: 0.0790
# Epoch [1/10], Loss: 1.4413
# Epoch [1/10], Valid Accuracy: 84.8100, Valid Loss: 0.8185
# Epoch [2/10], Loss: 0.6484
# Epoch [2/10], Valid Accuracy: 88.2500, Valid Loss: 0.5067
# Epoch [3/10], Loss: 0.4658
# Epoch [3/10], Valid Accuracy: 89.8400, Valid Loss: 0.4030
# Epoch [4/10], Loss: 0.3914
# Epoch [4/10], Valid Accuracy: 90.6200, Valid Loss: 0.3526
# Epoch [5/10], Loss: 0.3502
# Epoch [5/10], Valid Accuracy: 91.3600, Valid Loss: 0.3217
# Epoch [6/10], Loss: 0.3233
# Epoch [6/10], Valid Accuracy: 91.6500, Valid Loss: 0.3007
# Epoch [7/10], Loss: 0.3032
# Epoch [7/10], Valid Accuracy: 91.9800, Valid Loss: 0.2845
# Epoch [8/10], Loss: 0.2875
# Epoch [8/10], Valid Accuracy: 92.3300, Valid Loss: 0.2715
# Epoch [9/10], Loss: 0.2742
# Epoch [9/10], Valid Accuracy: 92.6100, Valid Loss: 0.2598
# Epoch [10/10], Loss: 0.2626
# Epoch [10/10], Valid Accuracy: 93.0400, Valid Loss: 0.2507
# CPU times: user 2min 17s, sys: 26.8 s, total: 2min 44s
# Wall time: 7min 49s

# %%
pd.DataFrame({'Learning Rate':learning_rates, 'Validation Accuracy': val_accs})
# Out:
#    Learning Rate  Validation Accuracy
# 0        1.00000                 9.85
# 1        0.10000                11.35
# 2        0.01000                94.88
# 3        0.00100                98.06
# 4        0.00010                97.67
# 5        0.00001                93.04

# %%
# %%time
learning_rates = np.linspace(0.0001, 0.001, num=5)
val_accs = []

for r in learning_rates:
    net = get_model()
    optimizer = optim.Adam(net.parameters(), lr=r)
    val_acc = train_model(train_loader, test_loader, num_epochs=10, model=net, optimizer=optimizer)[0]
    val_accs.append(val_acc)
# Out:
# Epoch [1/10], Loss: 0.4902
# Epoch [1/10], Valid Accuracy: 92.3100, Valid Loss: 0.2671
# Epoch [2/10], Loss: 0.2408
# Epoch [2/10], Valid Accuracy: 94.2200, Valid Loss: 0.2022
# Epoch [3/10], Loss: 0.1846
# Epoch [3/10], Valid Accuracy: 95.3400, Valid Loss: 0.1611
# Epoch [4/10], Loss: 0.1490
# Epoch [4/10], Valid Accuracy: 95.9100, Valid Loss: 0.1385
# Epoch [5/10], Loss: 0.1241
# Epoch [5/10], Valid Accuracy: 96.5200, Valid Loss: 0.1191
# Epoch [6/10], Loss: 0.1056
# Epoch [6/10], Valid Accuracy: 96.8200, Valid Loss: 0.1053
# Epoch [7/10], Loss: 0.0913
# Epoch [7/10], Valid Accuracy: 97.0600, Valid Loss: 0.0984
# Epoch [8/10], Loss: 0.0793
# Epoch [8/10], Valid Accuracy: 97.3500, Valid Loss: 0.0896
# Epoch [9/10], Loss: 0.0700
# Epoch [9/10], Valid Accuracy: 97.4000, Valid Loss: 0.0863
# Epoch [10/10], Loss: 0.0620
# Epoch [10/10], Valid Accuracy: 97.4900, Valid Loss: 0.0837
# Epoch [1/10], Loss: 0.3088
# Epoch [1/10], Valid Accuracy: 95.2400, Valid Loss: 0.1662
# Epoch [2/10], Loss: 0.1351
# Epoch [2/10], Valid Accuracy: 96.5400, Valid Loss: 0.1136
# Epoch [3/10], Loss: 0.0911
# Epoch [3/10], Valid Accuracy: 97.3300, Valid Loss: 0.0873
# Epoch [4/10], Loss: 0.0678
# Epoch [4/10], Valid Accuracy: 97.7300, Valid Loss: 0.0751
# Epoch [5/10], Loss: 0.0523
# Epoch [5/10], Valid Accuracy: 97.6500, Valid Loss: 0.0781
# Epoch [6/10], Loss: 0.0408
# Epoch [6/10], Valid Accuracy: 98.1600, Valid Loss: 0.0631
# Epoch [7/10], Loss: 0.0329
# Epoch [7/10], Valid Accuracy: 97.9300, Valid Loss: 0.0665
# Epoch [8/10], Loss: 0.0263
# Epoch [8/10], Valid Accuracy: 98.0000, Valid Loss: 0.0659
# Epoch [9/10], Loss: 0.0206
# Epoch [9/10], Valid Accuracy: 98.0700, Valid Loss: 0.0618
# Epoch [10/10], Loss: 0.0167
# Epoch [10/10], Valid Accuracy: 98.0000, Valid Loss: 0.0672
# Epoch [1/10], Loss: 0.2622
# Epoch [1/10], Valid Accuracy: 95.7100, Valid Loss: 0.1325
# Epoch [2/10], Loss: 0.1059
# Epoch [2/10], Valid Accuracy: 96.6700, Valid Loss: 0.1037
# Epoch [3/10], Loss: 0.0706
# Epoch [3/10], Valid Accuracy: 97.9100, Valid Loss: 0.0710
# Epoch [4/10], Loss: 0.0512
# Epoch [4/10], Valid Accuracy: 97.7900, Valid Loss: 0.0702
# Epoch [5/10], Loss: 0.0391
# Epoch [5/10], Valid Accuracy: 97.4700, Valid Loss: 0.0792
# Epoch [6/10], Loss: 0.0306
# Epoch [6/10], Valid Accuracy: 97.9900, Valid Loss: 0.0664
# Epoch [7/10], Loss: 0.0222
# Epoch [7/10], Valid Accuracy: 97.7500, Valid Loss: 0.0685
# Epoch [8/10], Loss: 0.0181
# Epoch [8/10], Valid Accuracy: 98.0100, Valid Loss: 0.0673
# Epoch [9/10], Loss: 0.0150
# Epoch [9/10], Valid Accuracy: 98.1500, Valid Loss: 0.0703
# Epoch [10/10], Loss: 0.0124
# Epoch [10/10], Valid Accuracy: 97.8800, Valid Loss: 0.0757
# Epoch [1/10], Loss: 0.2337
# Epoch [1/10], Valid Accuracy: 96.7400, Valid Loss: 0.1094
# Epoch [2/10], Loss: 0.0950
# Epoch [2/10], Valid Accuracy: 97.6200, Valid Loss: 0.0805
# Epoch [3/10], Loss: 0.0655
# Epoch [3/10], Valid Accuracy: 97.8600, Valid Loss: 0.0678
# Epoch [4/10], Loss: 0.0464
# Epoch [4/10], Valid Accuracy: 98.0500, Valid Loss: 0.0635
# Epoch [5/10], Loss: 0.0349
# Epoch [5/10], Valid Accuracy: 98.0500, Valid Loss: 0.0665
# Epoch [6/10], Loss: 0.0265
# Epoch [6/10], Valid Accuracy: 97.8900, Valid Loss: 0.0750
# Epoch [7/10], Loss: 0.0220
# Epoch [7/10], Valid Accuracy: 97.7100, Valid Loss: 0.0829
# Epoch [8/10], Loss: 0.0185
# Epoch [8/10], Valid Accuracy: 97.9800, Valid Loss: 0.0772
# Epoch [9/10], Loss: 0.0165
# Epoch [9/10], Valid Accuracy: 97.9700, Valid Loss: 0.0828
# Epoch [10/10], Loss: 0.0129
# Epoch [10/10], Valid Accuracy: 97.9400, Valid Loss: 0.0813
# Epoch [1/10], Loss: 0.2220
# Epoch [1/10], Valid Accuracy: 96.5900, Valid Loss: 0.1086
# Epoch [2/10], Loss: 0.0927
# Epoch [2/10], Valid Accuracy: 96.8900, Valid Loss: 0.0963
# Epoch [3/10], Loss: 0.0624
# Epoch [3/10], Valid Accuracy: 97.4900, Valid Loss: 0.0758
# Epoch [4/10], Loss: 0.0446
# Epoch [4/10], Valid Accuracy: 97.7800, Valid Loss: 0.0758
# Epoch [5/10], Loss: 0.0358
# Epoch [5/10], Valid Accuracy: 97.8600, Valid Loss: 0.0694
# Epoch [6/10], Loss: 0.0284
# Epoch [6/10], Valid Accuracy: 97.9900, Valid Loss: 0.0758
# Epoch [7/10], Loss: 0.0261
# Epoch [7/10], Valid Accuracy: 97.4900, Valid Loss: 0.0887
# Epoch [8/10], Loss: 0.0204
# Epoch [8/10], Valid Accuracy: 97.7800, Valid Loss: 0.0869
# Epoch [9/10], Loss: 0.0182
# Epoch [9/10], Valid Accuracy: 98.0600, Valid Loss: 0.0821
# Epoch [10/10], Loss: 0.0182
# Epoch [10/10], Valid Accuracy: 97.7500, Valid Loss: 0.0940
# CPU times: user 1min 53s, sys: 23.3 s, total: 2min 17s
# Wall time: 6min 33s

# %%
pd.DataFrame({'Learning Rate':learning_rates, 'Validation Accuracy': val_accs})
# Out:
#    Learning Rate  Validation Accuracy
# 0       0.000100                97.49
# 1       0.000325                98.00
# 2       0.000550                97.88
# 3       0.000775                97.94
# 4       0.001000                97.75

# %% [markdown]
# ## Q 3.2

# %%
# %%time
hidden_layer_size = [10, 50, 100, 300, 1000, 2000]
val_accs = []

for m in hidden_layer_size:
    net = get_model(m)
    optimizer = optim.Adam(net.parameters(), lr=0.01)
    val_acc = train_model(train_loader, test_loader, num_epochs=10, model=net, optimizer=optimizer)[0]
    val_accs.append(val_acc)
# Out:
# Epoch [1/10], Loss: 0.4872
# Epoch [1/10], Valid Accuracy: 90.5100, Valid Loss: 0.3295
# Epoch [2/10], Loss: 0.3461
# Epoch [2/10], Valid Accuracy: 89.3700, Valid Loss: 0.3652
# Epoch [3/10], Loss: 0.3295
# Epoch [3/10], Valid Accuracy: 90.6900, Valid Loss: 0.3172
# Epoch [4/10], Loss: 0.3234
# Epoch [4/10], Valid Accuracy: 90.9500, Valid Loss: 0.3121
# Epoch [5/10], Loss: 0.3215
# Epoch [5/10], Valid Accuracy: 91.6000, Valid Loss: 0.2978
# Epoch [6/10], Loss: 0.3141
# Epoch [6/10], Valid Accuracy: 91.3500, Valid Loss: 0.3017
# Epoch [7/10], Loss: 0.3135
# Epoch [7/10], Valid Accuracy: 89.7700, Valid Loss: 0.3673
# Epoch [8/10], Loss: 0.3096
# Epoch [8/10], Valid Accuracy: 89.4600, Valid Loss: 0.3726
# Epoch [9/10], Loss: 0.3057
# Epoch [9/10], Valid Accuracy: 90.6300, Valid Loss: 0.3308
# Epoch [10/10], Loss: 0.3078
# Epoch [10/10], Valid Accuracy: 91.2200, Valid Loss: 0.3196
# Epoch [1/10], Loss: 0.2941
# Epoch [1/10], Valid Accuracy: 93.3700, Valid Loss: 0.2439
# Epoch [2/10], Loss: 0.2164
# Epoch [2/10], Valid Accuracy: 94.3300, Valid Loss: 0.2076
# Epoch [3/10], Loss: 0.1880
# Epoch [3/10], Valid Accuracy: 94.7400, Valid Loss: 0.1917
# Epoch [4/10], Loss: 0.1875
# Epoch [4/10], Valid Accuracy: 95.0200, Valid Loss: 0.1950
# Epoch [5/10], Loss: 0.1736
# Epoch [5/10], Valid Accuracy: 94.4500, Valid Loss: 0.2162
# Epoch [6/10], Loss: 0.1712
# Epoch [6/10], Valid Accuracy: 94.3800, Valid Loss: 0.2506
# Epoch [7/10], Loss: 0.1710
# Epoch [7/10], Valid Accuracy: 95.1800, Valid Loss: 0.2225
# Epoch [8/10], Loss: 0.1666
# Epoch [8/10], Valid Accuracy: 95.0400, Valid Loss: 0.2196
# Epoch [9/10], Loss: 0.1613
# Epoch [9/10], Valid Accuracy: 95.2000, Valid Loss: 0.2189
# Epoch [10/10], Loss: 0.1636
# Epoch [10/10], Valid Accuracy: 95.1300, Valid Loss: 0.2339
# Epoch [1/10], Loss: 0.2777
# Epoch [1/10], Valid Accuracy: 94.0600, Valid Loss: 0.2129
# Epoch [2/10], Loss: 0.2069
# Epoch [2/10], Valid Accuracy: 93.3600, Valid Loss: 0.2510
# Epoch [3/10], Loss: 0.1957
# Epoch [3/10], Valid Accuracy: 94.6700, Valid Loss: 0.2102
# Epoch [4/10], Loss: 0.1769
# Epoch [4/10], Valid Accuracy: 94.4100, Valid Loss: 0.2658
# Epoch [5/10], Loss: 0.1737
# Epoch [5/10], Valid Accuracy: 94.8700, Valid Loss: 0.2376
# Epoch [6/10], Loss: 0.1705
# Epoch [6/10], Valid Accuracy: 95.0300, Valid Loss: 0.2163
# Epoch [7/10], Loss: 0.1635
# Epoch [7/10], Valid Accuracy: 93.2200, Valid Loss: 0.3344
# Epoch [8/10], Loss: 0.1641
# Epoch [8/10], Valid Accuracy: 94.4900, Valid Loss: 0.2785
# Epoch [9/10], Loss: 0.1544
# Epoch [9/10], Valid Accuracy: 95.3200, Valid Loss: 0.2305
# Epoch [10/10], Loss: 0.1570
# Epoch [10/10], Valid Accuracy: 95.1200, Valid Loss: 0.2333
# Epoch [1/10], Loss: 0.2935
# Epoch [1/10], Valid Accuracy: 93.6100, Valid Loss: 0.2354
# Epoch [2/10], Loss: 0.2123
# Epoch [2/10], Valid Accuracy: 94.6400, Valid Loss: 0.2095
# Epoch [3/10], Loss: 0.1938
# Epoch [3/10], Valid Accuracy: 94.1100, Valid Loss: 0.2415
# Epoch [4/10], Loss: 0.1820
# Epoch [4/10], Valid Accuracy: 95.3700, Valid Loss: 0.2024
# Epoch [5/10], Loss: 0.1756
# Epoch [5/10], Valid Accuracy: 94.3200, Valid Loss: 0.2847
# Epoch [6/10], Loss: 0.1692
# Epoch [6/10], Valid Accuracy: 94.7700, Valid Loss: 0.2422
# Epoch [7/10], Loss: 0.1688
# Epoch [7/10], Valid Accuracy: 95.1900, Valid Loss: 0.2252
# Epoch [8/10], Loss: 0.1578
# Epoch [8/10], Valid Accuracy: 95.3000, Valid Loss: 0.2447
# Epoch [9/10], Loss: 0.1507
# Epoch [9/10], Valid Accuracy: 95.6400, Valid Loss: 0.2616
# Epoch [10/10], Loss: 0.1512
# Epoch [10/10], Valid Accuracy: 95.3700, Valid Loss: 0.2611
# Epoch [1/10], Loss: 0.3144
# Epoch [1/10], Valid Accuracy: 93.5100, Valid Loss: 0.2615
# Epoch [2/10], Loss: 0.2211
# Epoch [2/10], Valid Accuracy: 94.9800, Valid Loss: 0.2211
# Epoch [3/10], Loss: 0.1943
# Epoch [3/10], Valid Accuracy: 95.2900, Valid Loss: 0.1988
# Epoch [4/10], Loss: 0.1879
# Epoch [4/10], Valid Accuracy: 95.4000, Valid Loss: 0.2102
# Epoch [5/10], Loss: 0.1766
# Epoch [5/10], Valid Accuracy: 94.6200, Valid Loss: 0.2489
# Epoch [6/10], Loss: 0.1632
# Epoch [6/10], Valid Accuracy: 95.1000, Valid Loss: 0.2333
# Epoch [7/10], Loss: 0.1596
# Epoch [7/10], Valid Accuracy: 95.4700, Valid Loss: 0.2636
# Epoch [8/10], Loss: 0.1600
# Epoch [8/10], Valid Accuracy: 95.7500, Valid Loss: 0.2329
# Epoch [9/10], Loss: 0.1561
# Epoch [9/10], Valid Accuracy: 95.6100, Valid Loss: 0.2414
# Epoch [10/10], Loss: 0.1450
# Epoch [10/10], Valid Accuracy: 95.7200, Valid Loss: 0.2491
# Epoch [1/10], Loss: 0.3381
# Epoch [1/10], Valid Accuracy: 94.0900, Valid Loss: 0.2245
# Epoch [2/10], Loss: 0.2185
# Epoch [2/10], Valid Accuracy: 94.5700, Valid Loss: 0.2136
# Epoch [3/10], Loss: 0.1903
# Epoch [3/10], Valid Accuracy: 94.6700, Valid Loss: 0.2455
# Epoch [4/10], Loss: 0.1904
# Epoch [4/10], Valid Accuracy: 94.0000, Valid Loss: 0.2541
# Epoch [5/10], Loss: 0.1740
# Epoch [5/10], Valid Accuracy: 95.3100, Valid Loss: 0.2130
# Epoch [6/10], Loss: 0.1683
# Epoch [6/10], Valid Accuracy: 95.4200, Valid Loss: 0.2215
# Epoch [7/10], Loss: 0.1571
# Epoch [7/10], Valid Accuracy: 95.2600, Valid Loss: 0.2169
# Epoch [8/10], Loss: 0.1596
# Epoch [8/10], Valid Accuracy: 95.2000, Valid Loss: 0.3094
# Epoch [9/10], Loss: 0.1538
# Epoch [9/10], Valid Accuracy: 95.4700, Valid Loss: 0.2360
# Epoch [10/10], Loss: 0.1485
# Epoch [10/10], Valid Accuracy: 95.9000, Valid Loss: 0.2663
# CPU times: user 2min 28s, sys: 31 s, total: 2min 59s
# Wall time: 7min 54s

# %%
pd.DataFrame({'hidden layer size': hidden_layer_size, 'Validation Accuracy': val_accs})
# Out:
#    Validation Accuracy  hidden layer size
# 0                91.22                 10
# 1                95.13                 50
# 2                95.12                100
# 3                95.37                300
# 4                95.72               1000
# 5                95.90               2000

# %% [markdown]
# For all hidden layer sizes, hidden_layer_size = 2000 seems to be the best with a Validation Accuracy of 95.90, however most of the models overfit: validation loss decreases while the training loss increases.

# %% [markdown]
# ## Q 3.3

# %%
# %%time
weight_decay = [0, 0.0001, 0.001, 0.01, 0.1, 0.3]
Train_loss = []
Validation_loss = []
Validation_accuracy = []

for decay_param in weight_decay:
    net = get_model(300)
    optimizer = optim.Adam(net.parameters(), lr=0.001, weight_decay = decay_param)
    val_acc, train_loss, val_loss = train_model(train_loader, test_loader, num_epochs=20, model=net, optimizer=optimizer)
    print(val_acc, train_loss, val_loss)
    Validation_accuracy.append(val_acc)
    Train_loss.append(round(train_loss,4))
    Validation_loss.append(round(val_loss,4))
# Out:
# Epoch [1/20], Loss: 0.2243
# Epoch [1/20], Valid Accuracy: 96.3900, Valid Loss: 0.1141
# Epoch [2/20], Loss: 0.0904
# Epoch [2/20], Valid Accuracy: 97.3700, Valid Loss: 0.0833
# Epoch [3/20], Loss: 0.0607
# Epoch [3/20], Valid Accuracy: 97.6400, Valid Loss: 0.0734
# Epoch [4/20], Loss: 0.0452
# Epoch [4/20], Valid Accuracy: 97.0800, Valid Loss: 0.0933
# Epoch [5/20], Loss: 0.0349
# Epoch [5/20], Valid Accuracy: 98.0000, Valid Loss: 0.0677
# Epoch [6/20], Loss: 0.0261
# Epoch [6/20], Valid Accuracy: 97.6500, Valid Loss: 0.0796
# Epoch [7/20], Loss: 0.0230
# Epoch [7/20], Valid Accuracy: 97.6900, Valid Loss: 0.0806
# Epoch [8/20], Loss: 0.0203
# Epoch [8/20], Valid Accuracy: 97.5600, Valid Loss: 0.0939
# Epoch [9/20], Loss: 0.0161
# Epoch [9/20], Valid Accuracy: 97.7000, Valid Loss: 0.0860
# Epoch [10/20], Loss: 0.0175
# Epoch [10/20], Valid Accuracy: 97.9000, Valid Loss: 0.0807
# Epoch [11/20], Loss: 0.0126
# Epoch [11/20], Valid Accuracy: 97.2600, Valid Loss: 0.1173
# Epoch [12/20], Loss: 0.0150
# Epoch [12/20], Valid Accuracy: 98.1800, Valid Loss: 0.0821
# Epoch [13/20], Loss: 0.0121
# Epoch [13/20], Valid Accuracy: 97.8000, Valid Loss: 0.1025
# Epoch [14/20], Loss: 0.0107
# Epoch [14/20], Valid Accuracy: 97.7300, Valid Loss: 0.1159
# Epoch [15/20], Loss: 0.0094
# Epoch [15/20], Valid Accuracy: 97.8600, Valid Loss: 0.1018
# Epoch [16/20], Loss: 0.0107
# Epoch [16/20], Valid Accuracy: 97.8800, Valid Loss: 0.1015
# Epoch [17/20], Loss: 0.0110
# Epoch [17/20], Valid Accuracy: 97.7400, Valid Loss: 0.1221
# Epoch [18/20], Loss: 0.0117
# Epoch [18/20], Valid Accuracy: 97.9300, Valid Loss: 0.1077
# Epoch [19/20], Loss: 0.0084
# Epoch [19/20], Valid Accuracy: 98.0000, Valid Loss: 0.1107
# Epoch [20/20], Loss: 0.0089
# Epoch [20/20], Valid Accuracy: 98.1000, Valid Loss: 0.1183
# 98.1 0.11826253603696824 0.00894039997793734
# Epoch [1/20], Loss: 0.2208
# Epoch [1/20], Valid Accuracy: 96.5500, Valid Loss: 0.1119
# Epoch [2/20], Loss: 0.0909
# 2      0.0847                97.30           0.0531        0.0010
# 3      0.1411                96.36           0.1555        0.0100
# 4      0.4352                90.23           0.4606        0.1000
# 5      0.7851                85.90           0.8112        0.3000

# %% [markdown]
# ## Q 3.4

# %%
def get_model_v2(M = 300, p=0):
    modules = []
    modules.append(nn.Linear(28*28, M))
    modules.append(nn.ReLU())
    if p > 0:
        modules.append(nn.Dropout(p))
    modules.append(nn.Linear(M, 10))
    return nn.Sequential(*modules).cuda()

# %%
# %%time
dropout = np.linspace(0, 1, num=5)
validation_accuracy_4 = []
Train_loss_4 = []
Validation_loss_4 = []

for d in dropout:
    net2 = get_model_v2(M = 300, p=d)
    optimizer = optim.Adam(net2.parameters(), lr=0.001)
    val_acc, train_loss, val_loss = train_model(train_loader, test_loader, num_epochs=20, model=net2, optimizer=optimizer)
    validation_accuracy_4.append(val_acc)
    Train_loss_4.append(round(train_loss,4))
    Validation_loss_4.append(round(val_loss,4))
# Out:
# Epoch [1/20], Loss: 0.2173
# Epoch [1/20], Valid Accuracy: 96.7900, Valid Loss: 0.1059
# Epoch [2/20], Loss: 0.0902
# Epoch [2/20], Valid Accuracy: 97.1000, Valid Loss: 0.0930
# Epoch [3/20], Loss: 0.0617
# Epoch [3/20], Valid Accuracy: 97.4400, Valid Loss: 0.0817
# Epoch [4/20], Loss: 0.0435
# Epoch [4/20], Valid Accuracy: 97.6100, Valid Loss: 0.0828
# Epoch [5/20], Loss: 0.0353
# Epoch [5/20], Valid Accuracy: 97.0600, Valid Loss: 0.0995
# Epoch [6/20], Loss: 0.0292
# Epoch [6/20], Valid Accuracy: 97.9600, Valid Loss: 0.0731
# Epoch [7/20], Loss: 0.0225
# Epoch [7/20], Valid Accuracy: 97.8400, Valid Loss: 0.0836
# Epoch [8/20], Loss: 0.0212
# Epoch [8/20], Valid Accuracy: 97.9600, Valid Loss: 0.0787
# Epoch [9/20], Loss: 0.0191
# Epoch [9/20], Valid Accuracy: 97.7800, Valid Loss: 0.0887
# Epoch [10/20], Loss: 0.0151
# Epoch [10/20], Valid Accuracy: 97.8200, Valid Loss: 0.0870
# Epoch [11/20], Loss: 0.0151
# Epoch [11/20], Valid Accuracy: 97.8000, Valid Loss: 0.0925
# Epoch [12/20], Loss: 0.0132
# Epoch [12/20], Valid Accuracy: 98.0900, Valid Loss: 0.0914
# Epoch [13/20], Loss: 0.0143
# Epoch [13/20], Valid Accuracy: 97.9200, Valid Loss: 0.1054
# Epoch [14/20], Loss: 0.0128
# Epoch [14/20], Valid Accuracy: 98.0900, Valid Loss: 0.0930
# Epoch [15/20], Loss: 0.0091
# Epoch [15/20], Valid Accuracy: 97.9400, Valid Loss: 0.1054
# Epoch [16/20], Loss: 0.0140
# Epoch [16/20], Valid Accuracy: 97.9100, Valid Loss: 0.1140
# Epoch [17/20], Loss: 0.0059
# Epoch [17/20], Valid Accuracy: 97.9400, Valid Loss: 0.1164
# Epoch [18/20], Loss: 0.0119
# Epoch [18/20], Valid Accuracy: 97.9800, Valid Loss: 0.1082
# Epoch [17/20], Loss: 2.3013
# Epoch [17/20], Valid Accuracy: 10.2900, Valid Loss: 2.3173
# Epoch [18/20], Loss: 2.3013
# Epoch [18/20], Valid Accuracy: 10.4100, Valid Loss: 2.3174
# Epoch [19/20], Loss: 2.3013
# Epoch [19/20], Valid Accuracy: 10.3900, Valid Loss: 2.3171
# Epoch [20/20], Loss: 2.3013
# Epoch [20/20], Valid Accuracy: 10.5000, Valid Loss: 2.3173
# CPU times: user 3min 59s, sys: 43.4 s, total: 4min 42s
# Wall time: 12min 56s

# %%
pd.DataFrame({'Dropout': dropout, 'Train loss': Train_loss_4, 
              'Validation loss': Validation_loss_4, 'Validation Accuracy': validation_accuracy_4})
# Out:
#    Dropout  Train loss  Validation Accuracy  Validation loss
# 0     0.00      0.1200                97.81           0.0098
# 1     0.25      0.0908                98.30           0.0254
# 2     0.50      0.0863                97.96           0.0627
# 3     0.75      0.0931                97.49           0.1796
# 4     1.00      2.3173                10.50           2.3013

# %% [markdown]
# Dropout parameter 0.25 achieves the best performance, because it reduce overfitting by zeroing out some of the neurons, while keep enough neurons to remain accurate.
# Dropout does help to increase testing accuracy(p = 0.25 or 0.5) compared to the model without a dropout(p = 0), and overall has better test accuracy than L2 regularization(except for p = 1, which means to drop all neurons).

# %% [markdown]
# ## Q 3.5

# %%
def get_model_v3(M = 500, p=0):
    modules = []
    modules.append(nn.Linear(28*28, M))
    modules.append(nn.ReLU())
    if p > 0:
        modules.append(nn.Dropout(p))
    modules.append(nn.Linear(M, int(0.2*M)))
    modules.append(nn.ReLU())
    modules.append(nn.Linear(int(0.2*M), 10))
    
    return nn.Sequential(*modules).cuda()

# %%
# %%time
hidden_layer_size = [300, 400, 500]
weight_decay = [0.0001, 0.001]
dropout = [0.25, 0.5]

df = pd.DataFrame({'hidden_layer_size': np.repeat(hidden_layer_size, 4), 
                   'weight_decay': np.tile(np.repeat(weight_decay,2),3),
                   'dropout': np.tile(dropout,6),
                    'Train_loss': np.zeros(12), 'Validation Accuracy': np.zeros(12), 'Validation_loss': np.zeros(12)})
print(df.head())
# Out:
#    Train_loss  Validation Accuracy  Validation_loss  dropout  \
# 0         0.0                  0.0              0.0     0.25
# 1         0.0                  0.0              0.0     0.50
# 2         0.0                  0.0              0.0     0.25
# 3         0.0                  0.0              0.0     0.50
# 4         0.0                  0.0              0.0     0.25
#
#    hidden_layer_size  weight_decay
# 0                300        0.0001
# 1                300        0.0001
# 2                300        0.0010
# 3                300        0.0010
# 4                400        0.0001
# CPU times: user 4 ms, sys: 4 ms, total: 8 ms
# Wall time: 6.4 ms

# %%
i = 0
for m in hidden_layer_size:
    for decay_param in weight_decay:
        for d in dropout:
            net3 = get_model_v3(M = m, p=d)
            optimizer = optim.Adam(net3.parameters(), lr=0.001, weight_decay = decay_param)
            val_acc, train_loss, val_loss = train_model(train_loader, test_loader, num_epochs=10, model=net3, optimizer=optimizer)
            df.iloc[i,0:3] = train_loss, val_acc, val_loss
            i += 1
# Out:
# Epoch [1/10], Loss: 0.2725
# Epoch [1/10], Valid Accuracy: 96.4400, Valid Loss: 0.1163
# Epoch [2/10], Loss: 0.1263
# Epoch [2/10], Valid Accuracy: 97.2200, Valid Loss: 0.0935
# Epoch [3/10], Loss: 0.0988
# Epoch [3/10], Valid Accuracy: 97.5600, Valid Loss: 0.0824
# Epoch [4/10], Loss: 0.0836
# Epoch [4/10], Valid Accuracy: 97.5300, Valid Loss: 0.0787
# Epoch [5/10], Loss: 0.0723
# Epoch [5/10], Valid Accuracy: 97.6800, Valid Loss: 0.0750
# Epoch [6/10], Loss: 0.0695
# Epoch [6/10], Valid Accuracy: 97.3400, Valid Loss: 0.0875
# Epoch [7/10], Loss: 0.0612
# Epoch [7/10], Valid Accuracy: 98.0100, Valid Loss: 0.0679
# Epoch [8/10], Loss: 0.0569
# Epoch [8/10], Valid Accuracy: 98.0300, Valid Loss: 0.0642
# Epoch [9/10], Loss: 0.0557
# Epoch [9/10], Valid Accuracy: 97.5100, Valid Loss: 0.0795
# Epoch [10/10], Loss: 0.0543
# Epoch [10/10], Valid Accuracy: 98.1300, Valid Loss: 0.0678
# Epoch [1/10], Loss: 0.3266
# Epoch [1/10], Valid Accuracy: 95.3500, Valid Loss: 0.1480
# Epoch [2/10], Loss: 0.1762
# Epoch [2/10], Valid Accuracy: 96.4500, Valid Loss: 0.1133
# Epoch [3/10], Loss: 0.1482
# Epoch [3/10], Valid Accuracy: 96.6100, Valid Loss: 0.1072
# Epoch [4/10], Loss: 0.1322
# Epoch [4/10], Valid Accuracy: 97.1300, Valid Loss: 0.0938
# Epoch [5/10], Loss: 0.1213
# Epoch [5/10], Valid Accuracy: 97.3000, Valid Loss: 0.0861
# Epoch [6/10], Loss: 0.1120
# Epoch [6/10], Valid Accuracy: 97.5200, Valid Loss: 0.0833
# Epoch [7/10], Loss: 0.1055
# Epoch [7/10], Valid Accuracy: 97.7200, Valid Loss: 0.0762
# Epoch [8/10], Loss: 0.0990
# Epoch [8/10], Valid Accuracy: 97.8600, Valid Loss: 0.0686
# Epoch [9/10], Loss: 0.0962
# Epoch [9/10], Valid Accuracy: 97.8100, Valid Loss: 0.0742
# Epoch [10/10], Loss: 0.0936
# Epoch [10/10], Valid Accuracy: 98.0200, Valid Loss: 0.0689
# Epoch [1/10], Loss: 0.2741
# Epoch [1/10], Valid Accuracy: 95.7100, Valid Loss: 0.1372
# Epoch [2/10], Loss: 0.1427
# Epoch [2/10], Valid Accuracy: 96.7500, Valid Loss: 0.1044
# Epoch [3/10], Loss: 0.1227
# Epoch [3/10], Valid Accuracy: 95.9900, Valid Loss: 0.1235
# Epoch [4/10], Loss: 0.1080
# Epoch [4/10], Valid Accuracy: 97.2900, Valid Loss: 0.0867
# Epoch [5/10], Loss: 0.1056
# Epoch [5/10], Valid Accuracy: 97.2400, Valid Loss: 0.0862
# Epoch [6/10], Loss: 0.1019
# Epoch [6/10], Valid Accuracy: 97.4800, Valid Loss: 0.0856
# Epoch [7/10], Loss: 0.0984
# Epoch [7/10], Valid Accuracy: 97.4300, Valid Loss: 0.0836
# Epoch [8/10], Loss: 0.0979
# Epoch [8/10], Valid Accuracy: 97.1100, Valid Loss: 0.0875
# Epoch [9/10], Loss: 0.0951
# Epoch [9/10], Valid Accuracy: 97.5400, Valid Loss: 0.0762
# Epoch [10/10], Loss: 0.0918
# Epoch [10/10], Valid Accuracy: 97.6300, Valid Loss: 0.0752
# Epoch [1/10], Loss: 0.3272
# Epoch [1/10], Valid Accuracy: 96.0100, Valid Loss: 0.1299
# Epoch [2/10], Loss: 0.1859
# Epoch [2/10], Valid Accuracy: 96.7700, Valid Loss: 0.1053
# Epoch [3/10], Loss: 0.1668
# Epoch [3/10], Valid Accuracy: 97.0600, Valid Loss: 0.0942
# Epoch [4/10], Loss: 0.1528
# Epoch [4/10], Valid Accuracy: 96.6700, Valid Loss: 0.1026
# Epoch [5/10], Loss: 0.1466
# Epoch [5/10], Valid Accuracy: 97.1700, Valid Loss: 0.0924
# Epoch [6/10], Loss: 0.1436
# Epoch [6/10], Valid Accuracy: 97.3900, Valid Loss: 0.0871
# Epoch [7/10], Loss: 0.1409
# Epoch [7/10], Valid Accuracy: 97.3700, Valid Loss: 0.0869
# Epoch [8/10], Loss: 0.1391
# Epoch [8/10], Valid Accuracy: 97.3800, Valid Loss: 0.0837
# Epoch [9/10], Loss: 0.1379
# Epoch [9/10], Valid Accuracy: 97.4900, Valid Loss: 0.0838
# Epoch [10/10], Loss: 0.1334
# Epoch [10/10], Valid Accuracy: 97.4600, Valid Loss: 0.0831
# Epoch [1/10], Loss: 0.2563
# Epoch [1/10], Valid Accuracy: 96.5400, Valid Loss: 0.1062
# Epoch [2/10], Loss: 0.1166
# Epoch [2/10], Valid Accuracy: 97.1100, Valid Loss: 0.0902
# Epoch [3/10], Loss: 0.0921
# Epoch [3/10], Valid Accuracy: 97.4600, Valid Loss: 0.0804
# Epoch [4/10], Loss: 0.0749
# Epoch [4/10], Valid Accuracy: 97.3800, Valid Loss: 0.0862
# Epoch [5/10], Loss: 0.0712
# Epoch [5/10], Valid Accuracy: 97.7100, Valid Loss: 0.0709
# Epoch [6/10], Loss: 0.0635
# Epoch [6/10], Valid Accuracy: 97.9500, Valid Loss: 0.0683
# Epoch [7/10], Loss: 0.0567
# Epoch [7/10], Valid Accuracy: 98.0500, Valid Loss: 0.0654
# Epoch [8/10], Loss: 0.0568
# Epoch [8/10], Valid Accuracy: 97.8400, Valid Loss: 0.0728
# Epoch [9/10], Loss: 0.0526
# Epoch [9/10], Valid Accuracy: 98.0100, Valid Loss: 0.0630
# Epoch [10/10], Loss: 0.0513
# Epoch [10/10], Valid Accuracy: 98.3100, Valid Loss: 0.0617
# Epoch [1/10], Loss: 0.3041
# Epoch [1/10], Valid Accuracy: 96.1900, Valid Loss: 0.1279
# Epoch [2/10], Loss: 0.1660
# Epoch [2/10], Valid Accuracy: 96.2100, Valid Loss: 0.1223
# Epoch [3/10], Loss: 0.1339
# Epoch [3/10], Valid Accuracy: 97.1800, Valid Loss: 0.0870
# Epoch [4/10], Loss: 0.1183
# Epoch [4/10], Valid Accuracy: 97.4300, Valid Loss: 0.0823
# Epoch [5/10], Loss: 0.1081
# Epoch [5/10], Valid Accuracy: 97.6700, Valid Loss: 0.0784
# Epoch [6/10], Loss: 0.1022
# Epoch [6/10], Valid Accuracy: 97.7000, Valid Loss: 0.0811
# Epoch [7/10], Loss: 0.0974
# Epoch [7/10], Valid Accuracy: 98.0100, Valid Loss: 0.0686
# Epoch [8/10], Loss: 0.0928
# Epoch [8/10], Valid Accuracy: 97.7600, Valid Loss: 0.0763
# Epoch [9/10], Loss: 0.0880
# Epoch [9/10], Valid Accuracy: 97.8900, Valid Loss: 0.0686
# Epoch [10/10], Loss: 0.0838
# Epoch [10/10], Valid Accuracy: 98.0600, Valid Loss: 0.0680
# Epoch [1/10], Loss: 0.2552
# Epoch [1/10], Valid Accuracy: 96.1600, Valid Loss: 0.1251
# Epoch [2/10], Loss: 0.1325
# Epoch [2/10], Valid Accuracy: 96.4800, Valid Loss: 0.1101
# Epoch [3/10], Loss: 0.1180
# Epoch [3/10], Valid Accuracy: 97.1700, Valid Loss: 0.0934
# Epoch [4/10], Loss: 0.1080
# Epoch [4/10], Valid Accuracy: 97.1600, Valid Loss: 0.0866
# Epoch [5/10], Loss: 0.1045
# Epoch [5/10], Valid Accuracy: 97.0300, Valid Loss: 0.0909
# Epoch [6/10], Loss: 0.1029
# Epoch [6/10], Valid Accuracy: 97.4900, Valid Loss: 0.0812
# Epoch [7/10], Loss: 0.0979
# Epoch [7/10], Valid Accuracy: 97.0600, Valid Loss: 0.0875
# Epoch [8/10], Loss: 0.0970
# Epoch [8/10], Valid Accuracy: 97.3400, Valid Loss: 0.0842
# Epoch [9/10], Loss: 0.0957
# Epoch [9/10], Valid Accuracy: 96.8600, Valid Loss: 0.0935
# Epoch [10/10], Loss: 0.0945
# Epoch [10/10], Valid Accuracy: 97.6700, Valid Loss: 0.0733
# Epoch [1/10], Loss: 0.3069
# Epoch [1/10], Valid Accuracy: 95.8300, Valid Loss: 0.1318
# Epoch [2/10], Loss: 0.1787
# Epoch [2/10], Valid Accuracy: 96.2800, Valid Loss: 0.1149
# Epoch [3/10], Loss: 0.1565
# Epoch [3/10], Valid Accuracy: 96.9000, Valid Loss: 0.0986
# Epoch [4/10], Loss: 0.1491
# Epoch [4/10], Valid Accuracy: 96.8100, Valid Loss: 0.0930
# Epoch [5/10], Loss: 0.1437
# Epoch [5/10], Valid Accuracy: 97.2000, Valid Loss: 0.0896
# Epoch [6/10], Loss: 0.1413
# Epoch [6/10], Valid Accuracy: 97.3200, Valid Loss: 0.0850
# Epoch [7/10], Loss: 0.1344
# Epoch [7/10], Valid Accuracy: 97.1100, Valid Loss: 0.0939
# Epoch [8/10], Loss: 0.1368
# Epoch [8/10], Valid Accuracy: 97.3000, Valid Loss: 0.0872
# Epoch [9/10], Loss: 0.1335
# Epoch [9/10], Valid Accuracy: 97.4300, Valid Loss: 0.0813
# Epoch [10/10], Loss: 0.1293
# Epoch [10/10], Valid Accuracy: 97.1700, Valid Loss: 0.0894
# Epoch [1/10], Loss: 0.2381
# Epoch [1/10], Valid Accuracy: 95.9800, Valid Loss: 0.1304
# Epoch [2/10], Loss: 0.1139
# Epoch [2/10], Valid Accuracy: 97.3700, Valid Loss: 0.0905
# Epoch [3/10], Loss: 0.0912
# Epoch [3/10], Valid Accuracy: 97.5700, Valid Loss: 0.0807
# Epoch [4/10], Loss: 0.0751
# Epoch [4/10], Valid Accuracy: 97.7600, Valid Loss: 0.0748
# Epoch [5/10], Loss: 0.0685
# Epoch [5/10], Valid Accuracy: 97.7300, Valid Loss: 0.0691
# Epoch [6/10], Loss: 0.0646
# Epoch [6/10], Valid Accuracy: 98.0000, Valid Loss: 0.0708
# Epoch [7/10], Loss: 0.0552
# Epoch [7/10], Valid Accuracy: 97.6300, Valid Loss: 0.0831
# Epoch [8/10], Loss: 0.0549
# Epoch [8/10], Valid Accuracy: 97.9100, Valid Loss: 0.0718
# Epoch [9/10], Loss: 0.0505
# Epoch [9/10], Valid Accuracy: 97.9300, Valid Loss: 0.0654
# Epoch [10/10], Loss: 0.0500
# Epoch [10/10], Valid Accuracy: 97.5100, Valid Loss: 0.0877
# Epoch [1/10], Loss: 0.2885
# Epoch [1/10], Valid Accuracy: 96.3000, Valid Loss: 0.1169
# Epoch [2/10], Loss: 0.1557
# Epoch [2/10], Valid Accuracy: 97.1500, Valid Loss: 0.0900
# Epoch [3/10], Loss: 0.1282
# Epoch [3/10], Valid Accuracy: 97.2100, Valid Loss: 0.0886
# Epoch [4/10], Loss: 0.1149
# Epoch [4/10], Valid Accuracy: 97.4000, Valid Loss: 0.0849
# Epoch [5/10], Loss: 0.1059
# Epoch [5/10], Valid Accuracy: 97.6500, Valid Loss: 0.0758
# Epoch [6/10], Loss: 0.0960
# Epoch [6/10], Valid Accuracy: 97.7700, Valid Loss: 0.0754
# Epoch [7/10], Loss: 0.0936
# Epoch [7/10], Valid Accuracy: 97.7600, Valid Loss: 0.0760
# Epoch [8/10], Loss: 0.0891
# Epoch [8/10], Valid Accuracy: 97.6100, Valid Loss: 0.0769
# Epoch [9/10], Loss: 0.0830
# Epoch [9/10], Valid Accuracy: 97.9900, Valid Loss: 0.0696
# Epoch [10/10], Loss: 0.0822
# Epoch [10/10], Valid Accuracy: 97.9200, Valid Loss: 0.0734
# Epoch [1/10], Loss: 0.2451
# Epoch [1/10], Valid Accuracy: 95.8000, Valid Loss: 0.1343
# Epoch [2/10], Loss: 0.1333
# Epoch [2/10], Valid Accuracy: 96.6400, Valid Loss: 0.1065
# Epoch [3/10], Loss: 0.1175
# Epoch [3/10], Valid Accuracy: 97.0300, Valid Loss: 0.0917
# Epoch [4/10], Loss: 0.1108
# Epoch [4/10], Valid Accuracy: 97.0700, Valid Loss: 0.0912
# Epoch [5/10], Loss: 0.1063
# Epoch [5/10], Valid Accuracy: 97.5100, Valid Loss: 0.0821
# Epoch [6/10], Loss: 0.1020
# Epoch [6/10], Valid Accuracy: 97.1900, Valid Loss: 0.0920
# Epoch [7/10], Loss: 0.0994
# Epoch [7/10], Valid Accuracy: 96.5300, Valid Loss: 0.1006
# Epoch [8/10], Loss: 0.0966
# Epoch [8/10], Valid Accuracy: 97.4800, Valid Loss: 0.0807
# Epoch [9/10], Loss: 0.0954
# Epoch [9/10], Valid Accuracy: 97.3100, Valid Loss: 0.0883
# Epoch [10/10], Loss: 0.0942
# Epoch [10/10], Valid Accuracy: 97.3800, Valid Loss: 0.0842
# Epoch [1/10], Loss: 0.2960
# Epoch [1/10], Valid Accuracy: 96.1400, Valid Loss: 0.1225
# Epoch [2/10], Loss: 0.1742
# Epoch [2/10], Valid Accuracy: 96.9700, Valid Loss: 0.1005
# Epoch [3/10], Loss: 0.1590
# Epoch [3/10], Valid Accuracy: 96.3400, Valid Loss: 0.1178
# Epoch [4/10], Loss: 0.1497
# Epoch [4/10], Valid Accuracy: 96.9500, Valid Loss: 0.0979
# Epoch [5/10], Loss: 0.1398
# Epoch [5/10], Valid Accuracy: 96.9700, Valid Loss: 0.0983
# Epoch [6/10], Loss: 0.1413
# Epoch [6/10], Valid Accuracy: 97.1000, Valid Loss: 0.0938
# Epoch [7/10], Loss: 0.1368
# Epoch [7/10], Valid Accuracy: 97.2300, Valid Loss: 0.0946
# Epoch [8/10], Loss: 0.1350
# Epoch [8/10], Valid Accuracy: 97.1100, Valid Loss: 0.0942
# Epoch [9/10], Loss: 0.1353
# Epoch [9/10], Valid Accuracy: 97.1200, Valid Loss: 0.0923
# Epoch [10/10], Loss: 0.1329
# Epoch [10/10], Valid Accuracy: 97.3700, Valid Loss: 0.0824

# %%
df.sort_values(['Validation Accuracy'], ascending = False)
# Out:
#     Train_loss  Validation Accuracy  Validation_loss  dropout  \
# 4     0.061655                98.31         0.051297     0.25
# 0     0.067766                98.13         0.054272     0.25
# 5     0.068044                98.06         0.083824     0.50
# 1     0.068863                98.02         0.093582     0.50
# 9     0.073385                97.92         0.082238     0.50
# 6     0.073280                97.67         0.094512     0.25
# 2     0.075247                97.63         0.091765     0.25
# 8     0.087734                97.51         0.049999     0.25
# 3     0.083120                97.46         0.133356     0.50
# 10    0.084220                97.38         0.094174     0.25
# 11    0.082394                97.37         0.132908     0.50
# 7     0.089357                97.17         0.129253     0.50
#
#     hidden_layer_size  weight_decay
# 4                 400        0.0001
# 0                 300        0.0001
# 5                 400        0.0001
# 1                 300        0.0001
# 9                 500        0.0001
# 6                 400        0.0010
# 2                 300        0.0010
# 8                 500        0.0001
# 3                 300        0.0010
# 10                500        0.0010
# 11                500        0.0010
# 7                 400        0.0010

# %% [markdown]
# The 3-layer NN has best validation accuracy when dropout rate = 0.25, hidden_layer_size = 400,
# weight_decay = 0.0001, which is similar to 2-layer NN, and the best validation accuracy(98.31) is also similar to 2-layer NN(98.30).
